# %%
import additionDeletion
additionDeletion.main()

# %%
import visualization
visualization.main()
# Out:
# Saved: C:\Users\kupautist\PycharmProjects\MyTrainings\outputs\daily_muscle_volume_big_and_small_4metrics.csv
# ...
# (         date  e1rm__big__arms  e1rm__big__back  e1rm__big__chest  \
#  0  2025-12-24        62.825000        72.459203        125.650000
#  1  2025-12-25       234.126684        18.375000        274.122489
#  2  2025-12-26        83.160000       261.360000          0.000000
#  3  2025-12-27        65.459756       105.600000         63.719512
#  4  2025-12-28       115.500000       363.000000          0.000000
#  ..        ...              ...              ...               ...
#  82 2026-03-16        23.275000         4.655000         46.550000
#  83 2026-03-17         0.000000         0.000000          0.000000
#  84 2026-03-18       217.594263       228.090968        374.123780
#  85 2026-03-19         0.000000         0.000000          0.000000
#  86 2026-03-20       205.791246       132.963164          0.000000
#
# ...
